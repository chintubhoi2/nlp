# %%
import pandas as pd
df = pd.read_csv("/content/extracted.csv")
df.head()
# Out:
#                                                 Text
# 0  Downloaded from: justpaste.it/1o73l\nStatistic...

# %%
df['Text']
# Out:
# 0    Downloaded from: justpaste.it/1o73l\nStatistic...
# Name: Text, dtype: object

# %%
docs = df['Text'][0]

# %%
docs = docs.replace("\n"," ")
docs
# Out:
# 'Downloaded from: justpaste.it/1o73l Statistics Questions   1. Where you have used Hypothesis Testing in your Machine learning Solution. 2. What kind of statistical tests you have performed in your ML Application 3. What do you understand by P Value? And what is use of it in ML? 4. Which type of error is severe Error, Type 1 or Type 2? And why with example. 5. Where we can use chi square and have used this test anywhere in your application 6. Can we use Chi square with Numerical dataset? If yes, give example. If no, give Reason? 7. What do you understand by ANOVA Testing? 8. Give me a scenario where you can use Z test and T test. 9. What do you understand by inferential Statistics? 10. When you are trying to calculate Std Deviation or Variance, why you used N-1 in Denominator? (Hint: Basel Connection) 11. What do you understand by right skewness, Give example? 12. What is difference between Normal distribution and Std Normal Distribution and Uniform Distribution? 13. What is differen
# ...

# %%
# !pip install rake-nltk -q

# %%
import nltk
from nltk.corpus import stopwords
 
nltk.download('stopwords')
stop = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from rake_nltk import Rake

# %%
r = Rake(stopwords=stop,punctuations = [')','(',',',':','.','?','.','/',').'])

# %%
r.extract_keywords_from_text(docs)

# %%
phrase_df = pd.DataFrame(r.get_ranked_phrases_with_scores(),columns = ['score','phrase'])
phrase_df
# Out:
#          score                                             phrase
# 0    46.875000  particular 30 days data science interview prep...
# 1    31.363889                          1 tail test & 2 tail test
# 2    22.944444                        train & test split function
# 3    19.833333                      know soil & weather condition
# 4    16.500000                                    auc & roc curve
# ..         ...                                                ...
# 456   1.000000                                                 15
# 457   1.000000                                                 14
# 458   1.000000                                                 13
# 459   1.000000                                                 12
# 460   1.000000                                                 11
#
# [461 rows x 2 columns]

# %%
phrase_df.loc[phrase_df.score>5]
# Out:
#         score                                             phrase
# 0   46.875000  particular 30 days data science interview prep...
# 1   31.363889                          1 tail test & 2 tail test
# 2   22.944444                        train & test split function
# 3   19.833333                      know soil & weather condition
# 4   16.500000                                    auc & roc curve
# 5   14.357143                    security & surveillance project
# 6   13.641026                        please explain random state
# 7   13.641026                    please explain confusion matrix
# 8   13.611111                                   ever done f test
# 9   13.041667                                         used n - 1
# 10  13.000000                             graph - based approach
# 11  12.875000                       1o73l statistics questions 1
# 12  12.666667                              architecture -- let ’
# ...

# %%
phrase_df.iloc[0]['phrase']
# Out:
# 'particular 30 days data science interview preparation course'
